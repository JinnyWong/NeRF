# %% [markdown]
# # Reconstruct 3D Scenes with Nerfstudio's Splatfacto model.
#
# [Splatfacto](https://docs.nerf.studio/nerfology/methods/splat.html) is Nerfstudio's implementation of 3D Gaussian Splatting. It represents radiance fields by explicitly storing a collection of 3D volumetric gaussians.

# %% [markdown]
# ## 1. Install requirements & dependencies

# %%
# !curl -L "https://github.com/OutofAi/tiny-cuda-nn-wheels/releases/download/Kaggle-P100/tinycudann-1.7-cp310-cp310-linux_x86_64.whl" -o tinycudann-1.7-cp310-cp310-linux_x86_64.whl
# !python -m pip install tinycudann-1.7-cp310-cp310-linux_x86_64.whl --force-reinstall --no-cache-dir
import tinycudann as tcnn

# %%
# !pip install nerfstudio

# %% [markdown]
# ## 2. Training

# %%
# !ns-train splatfacto --viewer.websocket-port 7007 --viewer.make-share-url True nerfstudio-data --data /kaggle/input/tanks-and-temple-m60-colmap-preprocessed/m60
# Out:
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26430 (88.10%)      28.876 ms            1 m, 43 s            22.18 M
# 26440 (88.13%)      28.749 ms            1 m, 42 s            22.28 M
# 26450 (88.17%)      28.857 ms            1 m, 42 s            22.19 M
# 26460 (88.20%)      28.924 ms            1 m, 42 s            22.14 M
# 26470 (88.23%)      28.861 ms            1 m, 41 s            22.20 M
# 26480 (88.27%)      28.791 ms            1 m, 41 s            22.26 M
# 26490 (88.30%)      28.614 ms            1 m, 40 s            22.38 M
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26440 (88.13%)      28.749 ms            1 m, 42 s            22.28 M
# 26450 (88.17%)      28.857 ms            1 m, 42 s            22.19 M
# 26460 (88.20%)      28.924 ms            1 m, 42 s            22.14 M
# 26470 (88.23%)      28.861 ms            1 m, 41 s            22.20 M
# 26480 (88.27%)      28.791 ms            1 m, 41 s            22.26 M
# 26490 (88.30%)      28.614 ms            1 m, 40 s            22.38 M
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26450 (88.17%)      28.857 ms            1 m, 42 s            22.19 M
# 26460 (88.20%)      28.924 ms            1 m, 42 s            22.14 M
# 26470 (88.23%)      28.861 ms            1 m, 41 s            22.20 M
# 26480 (88.27%)      28.791 ms            1 m, 41 s            22.26 M
# 26490 (88.30%)      28.614 ms            1 m, 40 s            22.38 M
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26460 (88.20%)      28.924 ms            1 m, 42 s            22.14 M
# 26470 (88.23%)      28.861 ms            1 m, 41 s            22.20 M
# 26480 (88.27%)      28.791 ms            1 m, 41 s            22.26 M
# 26490 (88.30%)      28.614 ms            1 m, 40 s            22.38 M
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26470 (88.23%)      28.861 ms            1 m, 41 s            22.20 M
# 26480 (88.27%)      28.791 ms            1 m, 41 s            22.26 M
# 26490 (88.30%)      28.614 ms            1 m, 40 s            22.38 M
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26480 (88.27%)      28.791 ms            1 m, 41 s            22.26 M
# 26490 (88.30%)      28.614 ms            1 m, 40 s            22.38 M
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26490 (88.30%)      28.614 ms            1 m, 40 s            22.38 M
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26500 (88.33%)      29.786 ms            1 m, 44 s            21.97 M
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# [03:47:58] Culled 187 gaussians (187 below alpha thresh, 0 too bigs, 398037 remaining)                 ]8;id=894337;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/models/splatfacto.py\splatfacto.py]8;;\:]8;id=35395;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/models/splatfacto.py#538\538]8;;\
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26510 (88.37%)      29.283 ms            1 m, 42 s            22.53 M
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26520 (88.40%)      28.051 ms            1 m, 37 s            22.98 M
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26530 (88.43%)      28.598 ms            1 m, 39 s            22.40 M
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26540 (88.47%)      28.956 ms            1 m, 40 s            22.15 M
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26550 (88.50%)      29.141 ms            1 m, 40 s            22.01 M
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26560 (88.53%)      29.095 ms            1 m, 40 s            22.02 M
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# 26650 (88.83%)      29.509 ms            1 m, 38 s            21.70 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26570 (88.57%)      28.934 ms            1 m, 39 s            22.14 M
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# 26650 (88.83%)      29.509 ms            1 m, 38 s            21.70 M
# 26660 (88.87%)      29.662 ms            1 m, 39 s            21.59 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26580 (88.60%)      28.747 ms            1 m, 38 s            22.28 M
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# 26650 (88.83%)      29.509 ms            1 m, 38 s            21.70 M
# 26660 (88.87%)      29.662 ms            1 m, 39 s            21.59 M
# 26670 (88.90%)      29.600 ms            1 m, 38 s            21.64 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26590 (88.63%)      29.289 ms            1 m, 39 s            22.06 M
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# 26650 (88.83%)      29.509 ms            1 m, 38 s            21.70 M
# 26660 (88.87%)      29.662 ms            1 m, 39 s            21.59 M
# 26670 (88.90%)      29.600 ms            1 m, 38 s            21.64 M
# 26680 (88.93%)      29.253 ms            1 m, 37 s            21.90 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26600 (88.67%)      30.413 ms            1 m, 43 s            21.70 M
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# 26650 (88.83%)      29.509 ms            1 m, 38 s            21.70 M
# 26660 (88.87%)      29.662 ms            1 m, 39 s            21.59 M
# 26670 (88.90%)      29.600 ms            1 m, 38 s            21.64 M
# 26680 (88.93%)      29.253 ms            1 m, 37 s            21.90 M
# 26690 (88.97%)      29.066 ms            1 m, 36 s            22.03 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# [03:48:01] Culled 141 gaussians (139 below alpha thresh, 2 too bigs, 397896 remaining)                 ]8;id=514003;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/models/splatfacto.py\splatfacto.py]8;;\:]8;id=519955;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/models/splatfacto.py#538\538]8;;\
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26610 (88.70%)      30.143 ms            1 m, 42 s            21.83 M
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# 26650 (88.83%)      29.509 ms            1 m, 38 s            21.70 M
# 26660 (88.87%)      29.662 ms            1 m, 39 s            21.59 M
# 26670 (88.90%)      29.600 ms            1 m, 38 s            21.64 M
# 26680 (88.93%)      29.253 ms            1 m, 37 s            21.90 M
# 26690 (88.97%)      29.066 ms            1 m, 36 s            22.03 M
# 26700 (89.00%)      30.792 ms            1 m, 41 s            21.11 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 26620 (88.73%)      29.388 ms            1 m, 39 s            21.91 M
# 26630 (88.77%)      29.855 ms            1 m, 40 s            21.44 M
# 26640 (88.80%)      29.719 ms            1 m, 39 s            21.55 M
# 26650 (88.83%)      29.509 ms            1 m, 38 s            21.70 M
# 26660 (88.87%)      29.662 ms            1 m, 39 s            21.59 M
# 26670 (88.90%)      29.600 ms            1 m, 38 s            21.64 M
# 26680 (88.93%)      29.253 ms            1 m, 37 s            21.90 M
# 26690 (88.97%)      29.066 ms            1 m, 36 s            22.03 M
# 26700 (89.00%)      30.792 ms            1 m, 41 s            21.11 M
# 26710 (89.03%)      30.095 ms            1 m, 39 s            21.76 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 
M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 29840 (99.47%)      29.415 ms            4 s, 706.421 ms      21.77 M
# 29850 (99.50%)      29.431 ms            4 s, 414.607 ms      21.76 M
# 29860 (99.53%)      28.964 ms            4 s, 54.918 ms       22.12 M
# 29870 (99.57%)      28.980 ms            3 s, 767.441 ms      22.10 M
# 29880 (99.60%)      29.165 ms            3 s, 499.855 ms      21.95 M
# 29890 (99.63%)      28.937 ms            3 s, 183.022 ms      22.12 M
# 29900 (99.67%)      30.256 ms            3 s, 25.615 ms       21.56 M
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 29850 (99.50%)      29.431 ms            4 s, 414.607 ms      21.76 M
# 29860 (99.53%)      28.964 ms            4 s, 54.918 ms       22.12 M
# 29870 (99.57%)      28.980 ms            3 s, 767.441 ms      22.10 M
# 29880 (99.60%)      29.165 ms            3 s, 499.855 ms      21.95 M
# 29890 (99.63%)      28.937 ms            3 s, 183.022 ms      22.12 M
# 29900 (99.67%)      30.256 ms            3 s, 25.615 ms       21.56 M
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# 29940 (99.80%)      28.697 ms            1 s, 721.836 ms      22.33 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 29860 (99.53%)      28.964 ms            4 s, 54.918 ms       22.12 M
# 29870 (99.57%)      28.980 ms            3 s, 767.441 ms      22.10 M
# 29880 (99.60%)      29.165 ms            3 s, 499.855 ms      21.95 M
# 29890 (99.63%)      28.937 ms            3 s, 183.022 ms      22.12 M
# 29900 (99.67%)      30.256 ms            3 s, 25.615 ms       21.56 M
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# 29940 (99.80%)      28.697 ms            1 s, 721.836 ms      22.33 M
# 29950 (99.83%)      28.878 ms            1 s, 443.895 ms      22.19 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 29870 (99.57%)      28.980 ms            3 s, 767.441 ms      22.10 M
# 29880 (99.60%)      29.165 ms            3 s, 499.855 ms      21.95 M
# 29890 (99.63%)      28.937 ms            3 s, 183.022 ms      22.12 M
# 29900 (99.67%)      30.256 ms            3 s, 25.615 ms       21.56 M
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# 29940 (99.80%)      28.697 ms            1 s, 721.836 ms      22.33 M
# 29950 (99.83%)      28.878 ms            1 s, 443.895 ms      22.19 M
# 29960 (99.87%)      28.599 ms            1 s, 143.950 ms      22.40 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 29880 (99.60%)      29.165 ms            3 s, 499.855 ms      21.95 M
# 29890 (99.63%)      28.937 ms            3 s, 183.022 ms      22.12 M
# 29900 (99.67%)      30.256 ms            3 s, 25.615 ms       21.56 M
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# 29940 (99.80%)      28.697 ms            1 s, 721.836 ms      22.33 M
# 29950 (99.83%)      28.878 ms            1 s, 443.895 ms      22.19 M
# 29960 (99.87%)      28.599 ms            1 s, 143.950 ms      22.40 M
# 29970 (99.90%)      28.593 ms            857.776 ms           22.40 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 29890 (99.63%)      28.937 ms            3 s, 183.022 ms      22.12 M
# 29900 (99.67%)      30.256 ms            3 s, 25.615 ms       21.56 M
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# 29940 (99.80%)      28.697 ms            1 s, 721.836 ms      22.33 M
# 29950 (99.83%)      28.878 ms            1 s, 443.895 ms      22.19 M
# 29960 (99.87%)      28.599 ms            1 s, 143.950 ms      22.40 M
# 29970 (99.90%)      28.593 ms            857.776 ms           22.40 M
# 29980 (99.93%)      28.689 ms            573.789 ms           22.32 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)       Vis Rays / Sec       Train Iter (time)    ETA (time)           Train Rays / Sec
# --------------------------------------------------------------------------------------------------------
# 29900 (99.67%)      30.256 ms            3 s, 25.615 ms       21.56 M
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# 29940 (99.80%)      28.697 ms            1 s, 721.836 ms      22.33 M
# 29950 (99.83%)      28.878 ms            1 s, 443.895 ms      22.19 M
# 29960 (99.87%)      28.599 ms            1 s, 143.950 ms      22.40 M
# 29970 (99.90%)      28.593 ms            857.776 ms           22.40 M
# 29980 (99.93%)      28.689 ms            573.789 ms           22.32 M
# 29990 (99.97%)      28.740 ms            287.402 ms           22.29 M
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# Step (% Done)
# --------------------
# 29910 (99.70%)      29.723 ms            2 s, 675.031 ms      22.19 M
# 29920 (99.73%)      28.332 ms            2 s, 266.544 ms      22.81 M
# 29930 (99.77%)      28.696 ms            2 s, 8.728 ms        22.32 M
# 29940 (99.80%)      28.697 ms            1 s, 721.836 ms      22.33 M
# 29950 (99.83%)      28.878 ms            1 s, 443.895 ms      22.19 M
# 29960 (99.87%)      28.599 ms            1 s, 143.950 ms      22.40 M
# 29970 (99.90%)      28.593 ms            857.776 ms           22.40 M
# 29980 (99.93%)      28.689 ms            573.789 ms           22.32 M
# 29990 (99.97%)      28.740 ms            287.402 ms           22.29 M
# 29999 (100.00%)
# ----------------------------------------------------------------------------------------------------
# Viewer at: http://localhost:7007 or https://durable-decompose.share.viser.studio
# ╭───────────────────────────────── 🎉 Training Finished 🎉 ─────────────────────────────────╮
# │                        ╷                                                                  │
# │   Config File          │ outputs/unnamed/splatfacto/2024-06-07_033205/config.yml          │
# │   Checkpoint Directory │ outputs/unnamed/splatfacto/2024-06-07_033205/nerfstudio_models   │
# │                        ╵                                                                  │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
#                                                    Use ctrl+c to quit
# (viser) Connection opened (2, 1 total), 1644 persistent messages
# (viser) Connection opened (3, 1 total), 1644 persistent messages
# (viser) Connection closed (3, 0 total)
# (viser) Connection opened (4, 1 total), 1644 persistent messages
# (viser) Connection closed (4, 0 total)
# (viser) Connection opened (5, 1 total), 1654 persistent messages
# ^C
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/nerfstudio/scripts/train.py", line 189, in launch
#     main_func(local_rank=0, world_size=world_size, config=config)
#   File "/opt/conda/lib/python3.10/site-packages/nerfstudio/scripts/train.py", line 100, in train_loop
#     trainer.train()
#   File "/opt/conda/lib/python3.10/site-packages/nerfstudio/engine/trainer.py", line 306, in train
#     self._after_train()
#   File "/opt/conda/lib/python3.10/site-packages/nerfstudio/engine/trainer.py", line 340, in _after_train
#     self._train_complete_viewer()
#   File "/opt/conda/lib/python3.10/site-packages/nerfstudio/utils/decorators.py", line 58, in wrapper
#     ret = func(self, *args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/nerfstudio/engine/trainer.py", line 395, in _train_complete_viewer
#     time.sleep(0.01)
# KeyboardInterrupt
#
# Printing profiling stats, from longest to shortest duration in seconds
# Trainer.train_iteration: 0.0256
# VanillaPipeline.get_train_loss_dict: 0.0213
# (viser) Disconnected from share URL
# (viser) Connection closed (5, 0 total)

# %% [markdown]
# ## 3. Render & export

# %% [markdown]
# First, create a path for the camera to follow. This can be done in the viewer under the "RENDER" tab. Orient your 3D view to the location where you wish the video to start, then press "ADD CAMERA". This will set the first camera key frame. Continue to new viewpoints adding additional cameras to create the camera path. Once satisfied, press "RENDER" which will display a modal that contains the command needed to render the video.

# %%
# !ns-render camera-path --load-config outputs/unnamed/splatfacto/2024-06-07_033205/config.yml --camera-path-filename /kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/camera_paths/2024-06-07-03-32-15.json --output-path renders/2024-06-07_033205/2024-06-07-03-32-15.mp4
# Out:
# 2024-06-07 04:32:57.461576: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 04:32:57.461639: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 04:32:57.463183: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading latest checkpoint from load_dir
# ✅ Done loading checkpoint from outputs/unnamed/splatfacto/2024-06-07_033205/nerfstudio_models/step-000029999.ckpt
# Creating trajectory video
# 🎥 Rendering 🎥 ━━━━━━━━━━━━━━━━━━━━━━ 420/420(100.0%) 10.73 fps 0:00:00 0:00:3900:3900:37
# ╭──────────────────── 🎉 Render Complete 🎉 ────────────────────╮
# │         ╷                                                     │
# │   Video │ renders/2024-06-07_033205/2024-06-07-03-32-15.mp4   │
# │         ╵                                                     │
# ╰───────────────────────────────────────────────────────────────╯

# %% [markdown]
# Generate `.ply` export of Gaussian Splat, which is ingestible by a variety of online third-party splat viewers like Spline and Three.js Viewer.

# %%
# !ns-export gaussian-splat --load-config outputs/unnamed/splatfacto/2024-06-07_033205/config.yml --output-dir exports/splat/
# Out:
# 2024-06-07 04:34:09.955301: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 04:34:09.955362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 04:34:09.956864: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [04:34:24] Auto image downscale factor of 4                                                 ]8;id=458156;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/data/dataparsers/nerfstudio_dataparser.py\nerfstudio_dataparser.py]8;;\:]8;id=86864;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/data/dataparsers/nerfstudio_dataparser.py#484\484]8;;\
# Loading latest checkpoint from load_dir
# ✅ Done loading checkpoint from outputs/unnamed/splatfacto/2024-06-07_033205/nerfstudio_models/step-000029999.ckpt

# %% [markdown]
# ## 4. Evaluation
# Calculate the PSNR of trained Splatfacto model and save to a `.json` file.

# %%
# !ns-eval --load-config=outputs/unnamed/splatfacto/2024-06-07_033205/config.yml --output-path=eval_output.json
# Out:
# 2024-06-07 04:35:51.525692: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 04:35:51.525754: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 04:35:51.527329: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [04:36:06] Auto image downscale factor of 4                                                 ]8;id=572089;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/data/dataparsers/nerfstudio_dataparser.py\nerfstudio_dataparser.py]8;;\:]8;id=713521;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/data/dataparsers/nerfstudio_dataparser.py#484\484]8;;\
# Loading latest checkpoint from load_dir
# ✅ Done loading checkpoint from outputs/unnamed/splatfacto/2024-06-07_033205/nerfstudio_models/step-000029999.ckpt
# [04:36:11] Caching / undistorting eval images                                             ]8;id=926978;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/data/datamanagers/full_images_datamanager.py\full_images_datamanager.py]8;;\:]8;id=94256;file:///opt/conda/lib/python3.10/site-packages/nerfstudio/data/datamanagers/full_images_datamanager.py#183\183]8;;\
# Caching / undistorting eval images ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00m 0:00:01
# Evaluating all eval images... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0:00:02 31/31 27/31
# Saved results to: eval_output.json

# %% [markdown]
# ## 5. Zip and download to local

# %%
# !zip /kaggle/working/video /kaggle/working/renders/2024-06-07_033205/2024-06-07-03-32-15.mp4
# Out:
#   adding: kaggle/working/renders/2024-06-07_033205/2024-06-07-03-32-15.mp4 (deflated 0%)

# %%
# !zip -r /kaggle/working/splatfacto-model /kaggle/working/outputs/unnamed/splatfacto
# Out:
#   adding: kaggle/working/outputs/unnamed/splatfacto/ (stored 0%)
#   adding: kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/ (stored 0%)
#   adding: kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/dataparser_transforms.json (deflated 63%)
#   adding: kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/config.yml (deflated 73%)
#   adding: kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/camera_paths/ (stored 0%)
#   adding: kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/camera_paths/2024-06-07-03-32-15.json (deflated 66%)
#   adding: kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/nerfstudio_models/ (stored 0%)
#   adding: kaggle/working/outputs/unnamed/splatfacto/2024-06-07_033205/nerfstudio_models/step-000029999.ckpt (deflated 7%)

# %%
# !zip -r /kaggle/working/splat /kaggle/working/exports/splat
# Out:
#   adding: kaggle/working/exports/splat/ (stored 0%)
#   adding: kaggle/working/exports/splat/splat.ply (deflated 10%)
