# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/dreamgaussian

# !pip install -q torch-ema einops tensorboardX plyfile dearpygui huggingface_hub diffusers==0.21.4 accelerate transformers xatlas
# !pip install -q trimesh PyMCubes pymeshlab rembg[gpu,cli] omegaconf ninja
# %cd /content/dreamgaussian
# !git clone --recursive https://github.com/ashawkey/diff-gaussian-rasterization
# !pip install -q ./diff-gaussian-rasterization
# !pip install -q ./simple-knn
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab/nvdiffrast-0.3.1-py3-none-any.whl
# !pip install -q git+https://github.com/ashawkey/kiuikit
# Out:
# /content
# Cloning into 'dreamgaussian'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 67 (delta 21), reused 14 (delta 13), pack-reused 24
# Receiving objects: 100% (67/67), 206.51 KiB | 12.91 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 74.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 80.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 37.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.1/230.1 kB 25.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 68.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.7/694.7 kB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.3/274.3 kB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 28.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 94.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 85.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 14.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.1/318.1 kB 31.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 85.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 31.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 36.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 92.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.7 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# /content/dreamgaussian
# Cloning into 'diff-gaussian-rasterization'...
# remote: Enumerating objects: 243, done.
# remote: Counting objects: 100% (243/243), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 243 (delta 154), reused 231 (delta 146), pack-reused 0
# Receiving objects: 100% (243/243), 526.80 KiB | 9.58 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# Submodule 'third_party/glm' (https://github.com/g-truc/glm.git) registered for path 'third_party/glm'
# Cloning into '/content/dreamgaussian/diff-gaussian-rasterization/third_party/glm'...
# remote: Enumerating objects: 59615, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 59615 (delta 0), reused 3 (delta 0), pack-reused 59610
# Receiving objects: 100% (59615/59615), 71.19 MiB | 10.82 MiB/s, done.
# Resolving deltas: 100% (45206/45206), done.
# Submodule path 'third_party/glm': checked out '5c46b9c07008ae65cb81ab79cd677ecc1934b903'
#   Preparing metadata (setup.py) ... done
#   Building wheel for diff-gaussian-rasterization (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for simple-knn (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for kiui (setup.py) ... done

# %%
NAME="teacher"
IMAGE="teacher.png"
IMAGE_PROCESSED="teacher_rgba.png"

# %%
# %run process.py data/{IMAGE}
# Out:
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx' to file '/root/.u2net/u2net.onnx'.
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 29.6GB/s]
# [INFO] loading image data/teacher.png...
# [INFO] background removal...
# [INFO] recenter...

# %%
#@title training!

# stage 1
# %run main.py --config configs/image.yaml input=data/{IMAGE_PROCESSED} save_path={NAME} elevation=0 force_cuda_rast=True

# stage 2
# %run main2.py --config configs/image.yaml input=data/{IMAGE_PROCESSED} save_path={NAME} elevation=0 force_cuda_rast=True
# Out:
# [INFO] load image from data/teacher_rgba.png...
# Number of points at initialisation :  5000
# [INFO] loading zero123...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/562 [00:00<?, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# unet/config.json:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/518 [00:00<?, ?B/s]
# clip_camera_projection/config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# image_encoder/config.json:   0%|          | 0.00/585 [00:00<?, ?B/s]
# (…)usion_pytorch_model.fp16_ema.safetensors:   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# (…)usion_pytorch_model.fp16_ema.safetensors:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# model.fp16_ema.safetensors:   0%|          | 0.00/608M [00:00<?, ?B/s]
# (…)usion_pytorch_model.fp16_ema.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# [INFO] loaded zero123!
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# 100%|██████████| 500/500 [01:18<00:00,  6.38it/s]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [INFO] save model to logs/teacher_model.ply.
# Tensor occ torch.Size([128, 128, 128]) torch.float32 cuda:0 ∈ [0.0, 79.66160583496094] μ = 0.1448725312948227 σ =
# 1.466565489768982
# [INFO] mesh cleaning: (14418, 3) --> (8415, 3), (28832, 3) --> (16826, 3)
# [INFO] marching cubes result: torch.Size([8415, 3]) (-0.6940976977348328-0.7011169195175171), torch.Size([16826, 3])
# [INFO] unwrap uv...
# /content/dreamgaussian/mesh.py:281: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at ../aten/src/ATen/native/Cross.cpp:62.)
#   face_normals = torch.cross(v1 - v0, v2 - v0)
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# [INFO] save model to logs/teacher_mesh.obj.
# [load_obj] use texture from: logs/teacher_mesh_albedo.png
# [load_obj] load texture: (1024, 1024, 3)
# [Mesh loading] v: torch.Size([8415, 3]), f: torch.Size([16826, 3])
# [Mesh loading] vn: torch.Size([8415, 3]), fn: torch.Size([16826, 3])
# [Mesh loading] vt: torch.Size([9721, 2]), ft: torch.Size([16826, 3])
# [INFO] load image from data/teacher_rgba.png...
# [INFO] loading zero123...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# [INFO] loaded zero123!
#   0%|          | 0/50 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# 100%|██████████| 50/50 [01:01<00:00,  1.23s/it]
# [INFO] save model to logs/teacher.obj.

# %%
#@title render a video for displaying

# the final mesh is saved to ./logs/NAME.obj
# %run -m kiui.render logs/{NAME}.obj --save_video {NAME}.mp4 --wogui --force_cuda_rast

from IPython.display import HTML
from base64 import b64encode

def show_video(video_path, video_width=450):
  video_file = open(video_path, "r+b").read()
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

show_video(f'{NAME}.mp4')
